# %% [markdown]
# # Step 3: Quantitative Analysis & Insights (Table 3 Generation)
# ---
# Trích xuất tất cả các files YAML đánh giá từ `run_experiments.sh` thành định dạng bảng `.csv` tổng quát (Tương đương Table 3 của Paper).

# %% [markdown]
# ## 3.0 Environment Setup (Colab T4 GPU)
# Khởi tạo Pandas, PyYAML và thiết lập môi trường phân tích dữ liệu.

# %%
# !pip install pandas pyyaml numpy

# %%
# !python aggregate_results.py --models sc_mamba_main_v1 sc_mamba_ablation_ci_only sc_mamba_ablation_no_filter

# %% [markdown]
# ## 3.1 Mean Absolute Scaled Error (MASE) DataFrame
# Trực quan hóa DataFrame tổng hợp từ kết quả của SC-Mamba so với Ablations.

# %%
import pandas as pd
import os

mase_file = 'table3_mase_benchmark.csv'
if os.path.exists(mase_file):
    df_mase = pd.read_csv(mase_file)
    display(df_mase)
else:
    print('Vui lòng chạy quá trình Benchmark trước khi load.')

# %% [markdown]
# ## 3.2 Probabilistic Forecast Uncertainty (CRPS-Proxy / NLL)
# Phân tích khoảng tin cậy của mô hình, đảm bảo khả năng Quantify rủi ro tốt hơn các Baseline tĩnh.

# %%
nll_file = 'table4_nll_benchmark.csv'
if os.path.exists(nll_file):
    df_nll = pd.read_csv(nll_file)
    display(df_nll)
else:
    print('Vui lòng chạy quá trình Benchmark trước khi load.')
