# %% [markdown]
# # Step 1: Zero-Shot Transfer & Ablation Studies
# ---
# Notebook này phục vụ quy trình đánh giá **Zero-Shot** cho kiến trúc `SC-Mamba` trên **17 Datasets** của GluonTS và kiểm tra sức mạnh của Graph Prior thông qua các mô hình Ablation.

# %% [markdown]
# ## 1.1 Environment Setup (Colab T4 GPU)
# Cài đặt PyTorch 2.4.0 (cu121) để tương thích chính xác với `causal_conv1d` và `mamba_ssm` compiled wheels.

# %%
# !pip uninstall -y torch torchvision torchaudio transformers sentence-transformers
# !pip install torch==2.4.0 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install transformers==4.39.3 packaging triton

# Tải prebuilt CUDNN wheels để tránh compile 45+ phút bằng ninja
# !wget -qO causal_conv1d.whl "https://github.com/Dao-AILab/causal-conv1d/releases/download/v1.4.0/causal_conv1d-1.4.0%2Bcu122torch2.4cxx11abiFALSE-cp312-cp312-linux_x86_64.whl"
# !wget -qO mamba_ssm.whl "https://github.com/state-spaces/mamba/releases/download/v2.2.4/mamba_ssm-2.2.4%2Bcu12torch2.4cxx11abiFALSE-cp312-cp312-linux_x86_64.whl"

# !pip install causal_conv1d.whl mamba_ssm.whl
# !pip install yfinance gluonts tqdm utilsforecast pyyaml pandas numpy

# %% [markdown]
# ## 1.2 Kiểm tra SC-Mamba Main (Gốc)
# Backbone CI nguyên bản kết hợp Causal Spectral Graph và NLL Loss.

# %%
# !python ../core/eval_real_dataset.py -m sc_mamba_main_v1

# %% [markdown]
# ## 1.3 Ablation 1: Channel-Independent Backbone Only
# Tắt Graph Message Passing và Variational Inference.

# %%
# !python ../core/eval_real_dataset.py -m sc_mamba_ablation_ci_only

# %% [markdown]
# ## 1.4 Ablation 2: No Spectral Filtering Threshold (Tắt $\tau$)
# Khảo sát Dense Graph so với Sparse Causal Graph.

# %%
# !python ../core/eval_real_dataset.py -m sc_mamba_ablation_no_filter
