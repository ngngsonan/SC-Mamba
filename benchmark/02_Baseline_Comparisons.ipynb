# %% [markdown]
# # Step 2: SOTA Baseline Comparisons
# ---
# Notebook này phục vụ quy trình đánh giá **Point 2.2** trong `walkthrough.md`.
# Chạy và ghi nhận kết quả điểm Point Forecast của các mô hình đại diện Rank A: `Mamba4cast`, `FourierGNN`, `DVGNN`, và `Chronos` trên cùng bộ 17 datasets.

# %% [markdown]
# ## 2.0 Environment Setup (Colab T4 GPU)
# Tương tự SC-Mamba, một số baselines như Mamba4cast cần môi trường CUDNN tối ưu.

# %%
# !pip uninstall -y torch torchvision torchaudio transformers sentence-transformers
# !pip install torch==2.4.0 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install transformers==4.39.3 packaging triton

# !wget -qO causal_conv1d.whl "https://github.com/Dao-AILab/causal-conv1d/releases/download/v1.4.0/causal_conv1d-1.4.0%2Bcu122torch2.4cxx11abiFALSE-cp312-cp312-linux_x86_64.whl"
# !wget -qO mamba_ssm.whl "https://github.com/state-spaces/mamba/releases/download/v2.2.4/mamba_ssm-2.2.4%2Bcu12torch2.4cxx11abiFALSE-cp312-cp312-linux_x86_64.whl"

# !pip install causal_conv1d.whl mamba_ssm.whl
# !pip install yfinance gluonts tqdm utilsforecast pyyaml pandas numpy

# %% [markdown]
# ## 2.1 Timeline Foundation Model: Chronos
# Sử dụng auto-regressive next-token prediction làm mốc benchmark chuẩn.

# %%
# !python ../core/eval_chronos.py --dataset_list all

# %% [markdown]
# ## 2.2 Spectral Graph Models: FourierGNN & DVGNN
# Chứng minh lợi thế của kiến trúc S4/Continuous Prior so với các GNN tuần tự cổ điển.

# %%
# !python ../core/eval_fouriergnn.py
# !python ../core/eval_dvgnn.py

# %% [markdown]
# ## 2.3 Original Zero-shot TSALM: Mamba4cast
# Áp dụng nguyên bản trọng số (Weights) được train trên Synthetic Data của cấu trúc CI-Mamba.

# %%
# !python ../core/eval_mamba4cast.py
